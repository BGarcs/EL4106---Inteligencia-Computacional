# %%
#TAREA 1 INTELIGENCIA COMPUTACIONAL

#Bastian Garces

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import time

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8c9af627-a690-4792-8da5-72ee7f14ec0d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c9af627-a690-4792-8da5-72ee7f14ec0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving magic04.data to magic04.data
# Saving magic04.names to magic04.names

# %%
ls
# Out:
# magic04.data  magic04.names  sample_data/

# %%
# PARTE 1 DE LA TAREA

# ACTIVIDAD 1


names = ['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1','fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist', 'class'] #Vector con el nombre de cada columna
df = pd.read_csv('magic04.data',names=names)

# %%
df

# %%
# ACTIVIDAD 2


H = df.loc[df['class'] == 'h'] #Arreglo donde se guardaran los hadrones
NH = df.loc[df['class'] == 'g'] #Arreglo donde se guardaran los no-hadrones

# %%
# ACTIVIDAD 3


#Primera caracteristica
bins1 = np.linspace(min(H['fLength'].min(),NH['fLength'].min()),max(H['fLength'].max(),NH['fLength'].max()),100) 
plt.hist(H['fLength'],bins1,alpha=0.8,label='Hadron')
plt.hist(NH['fLength'],bins1,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('flength')
plt.show()

#Segunda caracteristica
bins2 = np.linspace(min(H['fWidth'].min(),NH['fWidth'].min()),max(H['fWidth'].max(),NH['fWidth'].max()),100)
plt.hist(H['fWidth'],bins2,alpha=0.8,label='Hadron')
plt.hist(NH['fWidth'],bins2,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('fWidth')
plt.show()

#Tercera caracteristica
bins3 = np.linspace(min(H['fSize'].min(),NH['fSize'].min()),max(H['fSize'].max(),NH['fSize'].max()),100)
plt.hist(H['fSize'],bins3,alpha=0.8,label='Hadron')
plt.hist(NH['fSize'],bins3,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('fSize')
plt.show()

#Cuarta caracteristica
bins4 = np.linspace(min(H['fConc'].min(),NH['fConc'].min()),max(H['fConc'].max(),NH['fConc'].max()),100)
plt.hist(H['fConc'],bins4,alpha=0.8,label='Hadron')
plt.hist(NH['fConc'],bins4,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('fConc')
plt.show()

#Quinta caracteristica
bins5 = np.linspace(min(H['fConc1'].min(),NH['fConc1'].min()),max(H['fConc1'].max(),NH['fConc1'].max()),100)
plt.hist(H['fConc1'],bins5,alpha=0.8,label='Hadron')
plt.hist(NH['fConc1'],bins5,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('fConc1')
plt.show()

#Sexta caracteristica
bins6 = np.linspace(min(H['fAsym'].min(),NH['fAsym'].min()),max(H['fAsym'].max(),NH['fAsym'].max()),100)
plt.hist(H['fAsym'],bins6,alpha=0.8,label='Hadron')
plt.hist(NH['fAsym'],bins6,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('fAsym')
plt.show()

#Septima caracteristica
bins7 = np.linspace(min(H['fM3Long'].min(),NH['fM3Long'].min()),max(H['fM3Long'].max(),NH['fM3Long'].max()),100)
plt.hist(H['fM3Long'],bins7,alpha=0.8,label='Hadron')
plt.hist(NH['fM3Long'],bins7,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('fM3Long')
plt.show()

#Octava caracteristica
bins8 = np.linspace(min(H['fM3Trans'].min(),NH['fM3Trans'].min()),max(H['fM3Trans'].max(),NH['fM3Trans'].max()),100)
plt.hist(H['fM3Trans'],bins8,alpha=0.8,label='Hadron')
plt.hist(NH['fM3Trans'],bins8,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('fM3Trans')
plt.show()

#Novena caracteristica
bins9 = np.linspace(min(H['fAlpha'].min(),NH['fAlpha'].min()),max(H['fAlpha'].max(),NH['fAlpha'].max()),100)
plt.hist(H['fAlpha'],bins9,alpha=0.8,label='Hadron')
plt.hist(NH['fAlpha'],bins9,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('fAlpha')
plt.show()

#Decima caracteristica
bins10 = np.linspace(min(H['fDist'].min(),NH['fDist'].min()),max(H['fDist'].max(),NH['fDist'].max()),100)
plt.hist(H['fDist'],bins10,alpha=0.8,label='Hadron')
plt.hist(NH['fDist'],bins10,alpha=0.8,label='No-Hadron')
plt.legend(loc='upper right')
plt.title('fDist')
plt.show()

# %%
# ACTIVIDAD 4


df_1 = df.copy() #Hacemos una copia del dataframe original

#Aca cambiamos la columna class como: 0 si es no-hadron y 1 si es hadron
df_1['class'] = df_1['class'].replace({'g' : 0, 'h' : 1})

#Obtenemos la matriz de correlacion
Correla = df_1.corr()

#Aplicamos valor absoluto a las celdas de la matriz de correlacion
Correla_abs = abs(Correla)

# %%
# ACTIVIDAD 5 


#Obtenemos la columna de las clases
clases = Correla_abs['class']
print('Las caracteristicas mas correlacionadas con la clase')
print('ordenadas de mayor a menor son: ')
print(clases.sort_values(ascending=False))
# Out:
# Las caracteristicas mas correlacionadas con la clase
# ordenadas de mayor a menor son:
# class       1.000000
# fAlpha      0.460979
# fLength     0.307572
# fWidth      0.265596
# fM3Long     0.193409
# fAsym       0.173587
# fSize       0.117795
# fDist       0.065203
# fConc       0.024615
# fConc1      0.004797
# fM3Trans    0.003837
# Name: class, dtype: float64

# %%
# ACTIVIDAD 6


Correla_abs_lista = Correla_abs.unstack()

#Ordenamos lo anterior de mayor a menor
Correla_orden = Correla_abs_lista.sort_values(ascending = False)
#Dado que las caracteristicas tienen correlacion igual a 1 consigo mismo elimino
#Esos casos
Correla_orden2 = Correla_orden[Correla_orden<1]

#Para mostrar los 5 pares de caracteristicas que mas estan correlacionadas 
#se eliminaran el resto de pares
elim = list(range(0,10,2))+list(range(10,Correla_orden2.size))
mayores = Correla_orden2.drop(Correla_orden2.index[elim])
print('Los 5 pares de caracteristicas mas correlacionadas son:')
print(mayores)
# Out:
# Los 5 pares de caracteristicas mas correlacionadas son:
# fConc   fConc1     0.976412
# fSize   fConc      0.850850
# fConc1  fSize      0.808835
# fWidth  fLength    0.770512
#         fSize      0.717517
# dtype: float64

# %%
# ACTIVIDAD 7


#caracteristicas mas correlacionadas que son diferentes son 'fConc' y 'fConc1'
carac1 = Correla_orden2.index[0][0]
carac2 = Correla_orden2.index[0][1]
print('Las caracteristicas distintas mas correlacionadas son:')
print(carac1+' y '+carac2)
mayor = Correla_orden2[0]
print('Con un indice de correlacion de: '+str(mayor))
print('----------------------------------------------')
print('El grafico de dispersion de ambas caracteristicas es el siguiente:')
plt.scatter(df[carac1],df[carac2])
plt.xlabel(carac1)
plt.ylabel(carac2)
plt.title('Dispersion de caracteristicas mas correlacionadas')
# Out:
# Las caracteristicas distintas mas correlacionadas son:
# fConc1 y fConc
# Con un indice de correlacion de: 0.9764118508094787
# ----------------------------------------------
# El grafico de dispersion de ambas caracteristicas es el siguiente:
# Text(0.5, 1.0, 'Dispersion de caracteristicas mas correlacionadas')

# %%
# ACTIVIDAD 8


#Ordenamos la matriz unstackeada de la actividad 6 de menor a mayor
Correla_orden_d = Correla_abs_lista.sort_values(ascending = True)

#Para mostrar los 5 pares de caracteristicas menos correlacionadas
#se eliminaran el resto de pares
elim2 = list(range(0,10,2))+list(range(10,Correla_orden_d.size))
menores = Correla_orden_d.drop(Correla_orden_d.index[elim2])
print('Los 5 pares de caracteristicas menos correlacionadas son:')
print(menores)
# Out:
# Los 5 pares de caracteristicas menos correlacionadas son:
# fM3Trans  fAsym       0.002553
# class     fM3Trans    0.003837
# fAlpha    fM3Trans    0.004659
# fConc1    class       0.004797
# fAlpha    fLength     0.008777
# dtype: float64

# %%
# ACTIVIDAD 9 


#Caracteristicas menos correlacionadas son 'fM3Trans' y 'fAsym'
caract1 = Correla_orden_d.index[0][0]
caract2 = Correla_orden_d.index[0][1]
print('Las caracteristicas distintas menos correlacionadas son:')
print(caract1+' y '+caract2)
menor = Correla_orden_d[0]
print('Con un indice de correlacion de: '+str(menor))
print('----------------------------------------------')
print('El grafico de dispersion de ambas caracteristicas es el siguiente:')
plt.scatter(df[caract1],df[caract2])
plt.xlabel(caract1)
plt.ylabel(caract2)
plt.title('Dispersion de caracteristicas menos correlacionadas')
# Out:
# Las caracteristicas distintas menos correlacionadas son:
# fAsym y fM3Trans
# Con un indice de correlacion de: 0.0025528373198593904
# ----------------------------------------------
# El grafico de dispersion de ambas caracteristicas es el siguiente:
# Text(0.5, 1.0, 'Dispersion de caracteristicas menos correlacionadas')

# %%
# ACTIVIDAD 10


print('La matriz de correlacion es: ')
sns.heatmap(Correla_abs)
#Si a esa funcion despues le pongo annot = True puedo hacer un cambio
# Out:
# La matriz de correlacion es:

# %%
#PARTE 2

# ACTIVIDAD 11


df_2 = df.copy() #Copia del dataframe
corte = int(len(df_2.index)*0.8) #aca se debe hacer la separacion de datos
tole = 5 #Aca definiremos la tolerancia para considerar representativo
          #o no a los conjuntos, no puede ser 0

while 0==0: 
  #Para obtener los conjuntos desordenamos el dataframe df_2
  df_2_des = df_2.sample(frac=1).reset_index(drop=True)

  #El conjunto de entrenamiento tiene que tener el 80% de los datos iniciales
  #Y el conjunto de prueba debe tener el 20% restante
  Entrena = df_2_des.iloc[:corte,:].reset_index(drop=True)
  Prueba = df_2_des.iloc[corte:,:].reset_index(drop=True)

  #Tengo 12332 'g' y 6688 'h', tengo que ver que en proporcion 
  #el conjunto Entrena tenga 80% de datos 'g' y 20% de datos 'h'
  #y que el conjunto Prueba tenga 20% de datos de 'g' y 20% de datos 'h'
  #aproximadamente
  cont = 0
  for i in range(Entrena.shape[0]):
    if Entrena['class'][i] == 'g':
      cont = cont+1

  if 12332*0.8-cont<=tole:
    print('Se obtuvo representatividad')
    break
  print('No se ha logrado representatividad, por favor espere')
# Out:
# No se ha logrado representatividad, por favor espere
# No se ha logrado representatividad, por favor espere
# Se obtuvo representatividad

# %%
# ACTIVIDAD 12


#Separamos el conjunto de entrenamiento en hadron y no hadron
Entrena_H = Entrena[Entrena['class'] == 'h'].reset_index(drop=True) #Arreglo donde se guardaran los hadrones
Entrena_NH = Entrena[Entrena['class'] == 'g'].reset_index(drop=True) #Arreglo donde se guardaran los no-hadrones
bins = 50 #Bins a utilizar

#Obtenemos el histograma del conjunto de entrenamiento para #ambas clases

#Primero para los hadrones
filas_H = Entrena_H.shape[0]

#------------------------Caracteristica 1
hist1, binsedges1 = np.histogram(Entrena_H['fLength'],bins=bins) #Obtenemos el histograma
hist1 = hist1/filas_H #Lo normalizamos dividiendo por la cantidad de filas

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist1)):
  if hist1[i] == 0:
    hist1[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio1 = np.zeros(bins)
for i in range(len(binsedges1)-1):
  m = (binsedges1[i+1]+binsedges1[i])/2
  medio1[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio1,hist1,width=5,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fLength del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 2
hist2, binsedges2 = np.histogram(Entrena_H['fWidth'],bins=bins)
hist2 = hist2/filas_H

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist2)):
  if hist2[i] == 0:
    hist2[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio2 = np.zeros(bins)
for i in range(len(binsedges2)-1):
  m = (binsedges2[i+1]+binsedges2[i])/2
  medio2[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio2,hist2,width=4,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fWidth del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 3
hist3, binsedges3 = np.histogram(Entrena_H['fSize'],bins=bins)
hist3 = hist3/filas_H

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist3)):
  if hist3[i] == 0:
    hist3[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio3 = np.zeros(bins)
for i in range(len(binsedges3)-1):
  m = (binsedges3[i+1]+binsedges3[i])/2
  medio3[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio3,hist3,width=0.1,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fSize del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 4
hist4, binsedges4 = np.histogram(Entrena_H['fConc'],bins=bins)
hist4 = hist4/filas_H

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist4)):
  if hist4[i] == 0:
    hist4[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio4 = np.zeros(bins)
for i in range(len(binsedges4)-1):
  m = (binsedges4[i+1]+binsedges4[i])/2
  medio4[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio4,hist4,width=0.01,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fConc del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 5
hist5, binsedges5 = np.histogram(Entrena_H['fConc1'],bins=bins)
hist5 = hist5/filas_H

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist5)):
  if hist5[i] == 0:
    hist5[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio5 = np.zeros(bins)
for i in range(len(binsedges5)-1):
  m = (binsedges5[i+1]+binsedges5[i])/2
  medio5[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio5,hist5,width=0.01,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fConc1 del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 6
hist6, binsedges6 = np.histogram(Entrena_H['fAsym'],bins=bins)
hist6 = hist6/filas_H

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist6)):
  if hist6[i] == 0:
    hist6[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio6 = np.zeros(bins)
for i in range(len(binsedges6)-1):
  m = (binsedges6[i+1]+binsedges6[i])/2
  medio6[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio6,hist6,width=7,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fAsym del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 7
hist7, binsedges7 = np.histogram(Entrena_H['fM3Long'],bins=bins)
hist7 = hist7/filas_H

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist7)):
  if hist7[i] == 0:
    hist7[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio7 = np.zeros(bins)
for i in range(len(binsedges7)-1):
  m = (binsedges7[i+1]+binsedges7[i])/2
  medio7[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio7,hist7,width=5,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fM3Long del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 8
hist8, binsedges8 = np.histogram(Entrena_H['fM3Trans'],bins=bins)
hist8 = hist8/filas_H

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist8)):
  if hist8[i] == 0:
    hist8[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio8 = np.zeros(bins)
for i in range(len(binsedges8)-1):
  m = (binsedges8[i+1]+binsedges8[i])/2
  medio8[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio8,hist8,width=4,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fM3Trans del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 9
hist9, binsedges9 = np.histogram(Entrena_H['fAlpha'],bins=bins)
hist9 = hist9/filas_H

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist9)):
  if hist9[i] == 0:
    hist9[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio9 = np.zeros(bins)
for i in range(len(binsedges9)-1):
  m = (binsedges9[i+1]+binsedges9[i])/2
  medio9[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio9,hist9,width=2,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fAlpha del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 10
hist10, binsedges10 = np.histogram(Entrena_H['fDist'],bins=bins)
hist10 = hist10/filas_H

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist10)):
  if hist10[i] == 0:
    hist10[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio10 = np.zeros(bins)
for i in range(len(binsedges10)-1):
  m = (binsedges10[i+1]+binsedges10[i])/2
  medio10[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio10,hist10,width=2,label='Hadron',ec='black')
plt.legend(loc='upper right')
plt.title('fDist del conjunto de entrenamiento')
plt.show()

#-------------------------------------------------------------------------------
#-------------------------------------------------------------------------------

#Ahora para los no hadrones
filas_NH = Entrena_NH.shape[0]

#------------------------Caracteristica 1
hist11, binsedges11 = np.histogram(Entrena_NH['fLength'],bins=bins)
hist11 = hist11/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist11)):
  if hist11[i] == 0:
    hist11[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio11 = np.zeros(bins)
for i in range(len(binsedges11)-1):
  m = (binsedges11[i]+binsedges11[i+1])/2
  medio11[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio11,hist11,width=2,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fLength del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 2
hist12, binsedges12 = np.histogram(Entrena_NH['fWidth'],bins=bins)
hist12 = hist12/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist12)):
  if hist12[i] == 0:
    hist12[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio12 = np.zeros(bins)
for i in range(len(binsedges12)-1):
  m = (binsedges12[i]+binsedges12[i+1])/2
  medio12[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio12,hist12,width=2,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fWidth del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 3
hist13, binsedges13 = np.histogram(Entrena_NH['fSize'],bins=bins)
hist13 = hist13/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist13)):
  if hist13[i] == 0:
    hist13[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio13 = np.zeros(bins)
for i in range(len(binsedges13)-1):
  m = (binsedges13[i]+binsedges13[i+1])/2
  medio13[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio13,hist13,width=0.05,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fSize del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 4
hist14, binsedges14 = np.histogram(Entrena_NH['fConc'],bins=bins)
hist14 = hist14/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist14)):
  if hist14[i] == 0:
    hist14[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio14 = np.zeros(bins)
for i in range(len(binsedges14)-1):
  m = (binsedges14[i]+binsedges14[i+1])/2
  medio14[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio14,hist14,width=0.01,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fConc del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 5
hist15, binsedges15 = np.histogram(Entrena_NH['fConc1'],bins=bins)
hist15 = hist15/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist15)):
  if hist15[i] == 0:
    hist15[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio15 = np.zeros(bins)
for i in range(len(binsedges15)-1):
  m = (binsedges15[i]+binsedges15[i+1])/2
  medio15[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio15,hist15,width=0.01,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fConc1 del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 6
hist16, binsedges16 = np.histogram(Entrena_NH['fAsym'],bins=bins)
hist16 = hist16/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist16)):
  if hist16[i] == 0:
    hist16[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio16 = np.zeros(bins)
for i in range(len(binsedges16)-1):
  m = (binsedges16[i]+binsedges16[i+1])/2
  medio16[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio16,hist16,width=4,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fAsym del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 7
hist17, binsedges17 = np.histogram(Entrena_NH['fM3Long'],bins=bins)
hist17 = hist17/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist17)):
  if hist17[i] == 0:
    hist17[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio17 = np.zeros(bins)
for i in range(len(binsedges17)-1):
  m = (binsedges17[i]+binsedges17[i+1])/2
  medio17[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio17,hist17,width=2,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fM3Long del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 8
hist18, binsedges18 = np.histogram(Entrena_NH['fM3Trans'],bins=bins)
hist18 = hist18/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist18)):
  if hist18[i] == 0:
    hist18[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio18 = np.zeros(bins)
for i in range(len(binsedges18)-1):
  m = (binsedges18[i]+binsedges18[i+1])/2
  medio18[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio18,hist18,width=2,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fM3Trans del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 9
hist19, binsedges19 = np.histogram(Entrena_NH['fAlpha'],bins=bins)
hist19 = hist19/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist19)):
  if hist19[i] == 0:
    hist19[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio19 = np.zeros(bins)
for i in range(len(binsedges19)-1):
  m = (binsedges19[i]+binsedges19[i+1])/2
  medio19[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio19,hist19,width=2,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fAlpha del conjunto de entrenamiento')
plt.show()

#------------------------Caracteristica 10
hist20, binsedges20 = np.histogram(Entrena_NH['fDist'],bins=bins)
hist20 = hist20/filas_NH

#En este for nos encargamos de que los datos del histograma que tienen probabilidad
#0 pasen a tener una probabilidad muy pequeña, esto lo hacemos para evitar futuras 
#divisiones por 0
for i in range(len(hist20)):
  if hist20[i] == 0:
    hist20[i] = 0.0000001
#Las siguientes 4 lineas de codigo sirven para obtener un grafico del histograma
#obtenido, donde para localizar cada uno de los valores del histograma se esta
#ocupando el punto medio entre los bordes de cada bin
medio20 = np.zeros(bins)
for i in range(len(binsedges20)-1):
  m = (binsedges20[i]+binsedges20[i+1])/2
  medio20[i] = m
#Esto solo sirve para apreciar mejor el plot
plt.bar(medio20,hist20,width=3,label='No-Hadron',color='orange',ec='black')
plt.legend(loc='upper right')
plt.title('fDist del conjunto de entrenamiento')
plt.show()


#Arreglos donde guardo los histogramas segun su clase, lo usare para que la actividad 13
#pueda hacerse mas facil
histograma_H = [hist1,hist2,hist3,hist4,hist5,hist6,hist7,hist8,hist9,hist10]
histograma_NH = [hist11,hist12,hist13,hist14,hist15,hist16,hist17,hist18,hist19,hist20]

#Tiempo de ejecucion
tiempo_hist = time.time()

# %%
# ACTIVIDAD 13


#Debemos calcular la verosimilitud para cada dato del conjunto de prueba

#Vector donde se guardaran las verosimilitudes obtenidas de los histogramas 
#de la clase Hadron
Vero_Prueba_H = np.zeros(Prueba.shape[0])

#Calculamos la verosimilitud de cada dato perteneciente al dataframe Prueba
#Primero viendolo como si fuesen hadrones
for i in range(Prueba.shape[0]):
  caracteristicas = np.zeros(10)
  probabilidad = np.zeros(10)
  for j in range(10):
    #Obtenemos la caracteristica
    caracteristicas[j] = Prueba[names[j]][i]
    #Obtenemos en el que cae la caracteristica
    b = math.floor(bins * (caracteristicas[j] - Entrena_H[names[j]].min())/(Entrena_H[names[j]].max() - Entrena_H[names[j]].min()))
    if (caracteristicas[j]<=Entrena_H[names[j]].min()) or ((caracteristicas[j]>=Entrena_H[names[j]].max())):
      probabilidad[j] = 0.0000001
    else:
      probabilidad[j] = histograma_H[j][b]
  vero = np.prod(probabilidad)
  Vero_Prueba_H[i] = vero

#Ahora hacemos lo mismo pero con los no-hadrones

#Vector donde guardare las verosimilitudes asociadas a usar los histogramas
#de la clase no-hadron
Vero_Prueba_NH = np.zeros(Prueba.shape[0])

#Calculamos la verosimilitud de cada dato perteneciente al dataframe Prueba
# viendolo como si fuesen no-hadrones
for i in range(Prueba.shape[0]):
  caracteristicas = np.zeros(10)
  probabilidad = np.zeros(10)
  for j in range(10):
    #Obtenemos la caracteristica
    caracteristicas[j] = Prueba[names[j]][i]
    #Obtenemos en el que cae la caracteristica
    b = math.floor(bins * (caracteristicas[j] - Entrena_NH[names[j]].min())/(Entrena_NH[names[j]].max() - Entrena_NH[names[j]].min()))
    if (caracteristicas[j]<=Entrena_NH[names[j]].min()) or ((caracteristicas[j]>=Entrena_NH[names[j]].max())):
      probabilidad[j] = 0.0000001
    else:
      probabilidad[j] = histograma_NH[j][b]
  vero = np.prod(probabilidad)
  Vero_Prueba_NH[i] = vero

# %%
# ACTIVIDAD 14


#Arreglo donde guardo las divisiones de verosimilitudes
clas = np.zeros(Vero_Prueba_H.shape[0])

#En el arreglo clas calculo la division de verosimilitudes al considerar el dato
#del conjunto de prueba como caso hadron y clase no-Hadron
for i in range(Vero_Prueba_H.shape[0]):
  clas[i] = (Vero_Prueba_H[i])/(Vero_Prueba_NH[i])

#Creamos un vector con posibles valores de Theta
Theta = np.linspace(0,100,500)

#Vector donde se guardaran los verdaderos positivos (VP: Cuando digo es hadron 
# y efectivamente era hadron)
VP = np.zeros(len(Theta))

#Vector donde se guaradaran los falsos positivos (FP: Cuando digo es hadron 
#y era no-hadron)
FP = np.zeros(len(Theta))

#Vector donde se guardaran los verdaderos negativos (VN: Cuando digo es no-hadron
#y efectivamente era no-hadron)
VN = np.zeros(len(Theta))

#Vector donde se guardaran los falsos negativos (FN: Cuando digo es no-hadron
#y es hadron)
FN = np.zeros(len(Theta))

for i in range(len(Theta)):
  V_P = 0
  F_P = 0
  V_N = 0
  F_N = 0
  for j in range(Prueba.shape[0]):
    #Digo que es hadron
    if (clas[j] >= Theta[i]):
      clase = Prueba['class'][j]
      #Acerte
      if (clase == 'h'):
        V_P = V_P+1 
      #No acerte
      elif (clase == 'g'):
        F_P = F_P+1
    #Digo que es no-hadron
    elif (clas[j] < Theta[i]):
      clase = Prueba['class'][j]
      #No acerte
      if (clase == 'h'):
        F_N = F_N+1
      #acerte
      elif (clase == 'g'):
        V_N = V_N+1
  #Añado lo obtenido a los vectores VP, FP, VN y FN
  VP[i] = V_P
  FP[i] = F_P
  VN[i] = V_N
  FN[i] = F_N

#Calculamos la taza de verdaderos positivos y falsos positivos para cada theta
TVP = np.zeros(len(Theta))
TFP = np.zeros(len(Theta))
#Ademas se calculara el precission y el recall, datos a utilizar en la siguiente
#actividad
P = np.zeros(len(Theta))
R = np.zeros(len(Theta))
for i in range(len(Theta)):
  Verd_Pos = VP[i]
  Fals_Neg = FN[i]
  Fals_Pos = FP[i]
  Verd_Neg = VN[i]
  TVP[i] = Verd_Pos/(Verd_Pos+Fals_Neg)
  TFP[i] = Fals_Pos/(Fals_Pos+Verd_Neg)
  P[i] = Verd_Pos/(Verd_Pos+Fals_Pos)
  R[i] = Verd_Pos/(Verd_Pos+Fals_Neg)

#Obtenemos la curva ROC
cosa1 = [0,1]
cosa2 = [0,1]
plt.plot(cosa1,cosa2,color='red')
plt.plot(TFP,TVP,color='blue')
plt.xlabel('Tasa falsos positivos')
plt.ylabel('Tasa verdaderos positivos')
plt.title('Curva ROC')
plt.show()

# %%
# ACTIVIDAD 15 


#Generamos la curva precission-recall
algo1 = [1,0]
plt.plot(R,P,color='blue')
plt.plot(algo1,cosa1,color='red')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Curva Precision-Recall')
plt.show()

# %%
#PARTE 3


# ACTIVIDAD 16

#Obtenemos los promedios del conjunto de entrenamiento para cada caracteristica y clase
Prom_H = np.zeros(10)
Prom_NH = np.zeros(10)

for i in range(10):
  Prom_H[i] = np.mean(Entrena_H[names[i]])
  Prom_NH[i] = np.mean(Entrena_NH[names[i]])

#Con la finalidad de obtener la matriz de covarianza para el conjunto de entrenamiento
#de los hadrones y no hadrones, primero quitamos la columna 'class' de los conjuntos
#Y luego trasponemos el dataframe, de tal forma que las caracteristicas sean las filas
#y los datos las columnas
Entrena_H_SC = Entrena_H.iloc[:,:10].transpose()
Entrena_NH_SC = Entrena_NH.iloc[:,:10].transpose()

#Para obtener la matriz de covarianza pasamos los dataframes recien obtenidos
#a arrays (a matrices)
M_Entrena_H_SC = Entrena_H_SC.to_numpy()
M_Entrena_NH_SC = Entrena_NH_SC.to_numpy()

#Obtenemos las matrices de covarianza para cada clase
cov_H = np.cov(M_Entrena_H_SC)
cov_NH = np.cov(M_Entrena_NH_SC)

#Obtenemos las inversas de estas matrices
I_cov_H = np.linalg.inv(cov_H)
I_cov_NH = np.linalg.inv(cov_NH)

#Obtenemos los determinantes de las matrices de covarianza
det_cov_H = np.linalg.det(cov_H)
det_cov_NH = np.linalg.det(cov_NH)

#Tiempo de ejecucion
tiempo_gauss = time.time()

# %%
# ACTIVIDAD 17


#Definimos vectores en los que se guardaran los datos de las gaussianas obtenidas
gauss_H = np.zeros(Prueba.shape[0])
gauss_NH = np.zeros(Prueba.shape[0])

#Calculamos la verosimilitud de los elementos del conjunto de prueba 
#considerando como que son hadrones
for i in range(Prueba.shape[0]):
  caracteristicas = np.zeros(10)
  for j in range(10):
    #Obtenemos la caracteristica
    caracteristicas[j] = Prueba[names[j]][i]
  dato = caracteristicas - Prom_H #resta entre el vector de caracteristicas y vector de promedios
  tras = np.transpose(dato) #vector dato transpuesto
  p = np.dot(tras,I_cov_H) #calculamos la multiplicacion entre tras y la inversa de la matriz de covarianza
  ps = np.dot(p,dato) #calculamos la multiplicacion entre p y dato
  pi = math.pi #definicion del numero pi
  guassilla = (math.exp((-1/2)*ps)) / (math.sqrt(((2*pi)**(10))*det_cov_H))
  gauss_H[i] = guassilla

#Calculamos la verosimilitud de los elementos del conjunto de prueba
#considerando como que son no-hadrones
for i in range(Prueba.shape[0]):
  caracteristicas = np.zeros(10)
  for j in range(10):
    #Obtenemos la caracteristica
    caracteristicas[j] = Prueba[names[j]][i]
  dato = caracteristicas - Prom_NH #resta entre el vector de caracteristicas y vector de promedios
  tras = np.transpose(dato) #vector dato transpuesto
  p = np.dot(tras,I_cov_NH) #calculamos la multiplicacion entre tras y la inversa de la matriz de covarianza
  ps = np.dot(p,dato) #calculamos la multiplicacion entre p y dato
  pi = math.pi #definicion del numero pi
  guassilla = (math.exp((-1/2)*ps)) / (math.sqrt(((2*pi)**(10))*det_cov_NH))
  gauss_NH[i] = guassilla

# %%
# ACTIVIDAD 18


#Definimos el clasificador
clasi = np.zeros(Prueba.shape[0])
for i in range(Prueba.shape[0]):
  clasi[i] = gauss_H[i]/gauss_NH[i]

#Vector donde se guardaran los verdaderos positivos (VP: Cuando digo es hadron 
# y efectivamente era hadron)
VP_N = np.zeros(len(Theta))

#Vector donde se guaradaran los falsos positivos (FP: Cuando digo es hadron 
#y era no-hadron)
FP_N = np.zeros(len(Theta))

#Vector donde se guardaran los verdaderos negativos (VN: Cuando digo es no-hadron
#y efectivamente era no-hadron)
VN_N = np.zeros(len(Theta))

#Vector donde se guardaran los falsos negativos (FN: Cuando digo es no-hadron
#y es hadron)
FN_N = np.zeros(len(Theta))

for i in range(len(Theta)):
  V_P = 0
  F_P = 0
  V_N = 0
  F_N = 0
  for j in range(Prueba.shape[0]):
    #Digo que es hadron
    if (clasi[j] >= Theta[i]):
      clase = Prueba['class'][j]
      #Acerte
      if (clase == 'h'):
        V_P = V_P+1 
      #No acerte
      elif (clase == 'g'):
        F_P = F_P+1
    #Digo que es no-hadron
    elif (clasi[j] < Theta[i]):
      clase = Prueba['class'][j]
      #No acerte
      if (clase == 'h'):
        F_N = F_N+1
      #acerte
      elif (clase == 'g'):
        V_N = V_N+1
  #Añado lo obtenido a los vectores VP, FP, VN y FN
  VP_N[i] = V_P
  FP_N[i] = F_P
  VN_N[i] = V_N
  FN_N[i] = F_N

#Calculamos la taza de verdaderos positivos y falsos positivos para cada theta
TVP_N = np.zeros(len(Theta))
TFP_N = np.zeros(len(Theta))
#Ademas se calculara el precission y el recall, datos a utilizar en la siguiente
#actividad
P_N = np.zeros(len(Theta))
R_N = np.zeros(len(Theta))
for i in range(len(Theta)):
  Verd_Pos = VP_N[i]
  Fals_Neg = FN_N[i]
  Fals_Pos = FP_N[i]
  Verd_Neg = VN_N[i]
  TVP_N[i] = Verd_Pos/(Verd_Pos+Fals_Neg)
  TFP_N[i] = Fals_Pos/(Fals_Pos+Verd_Neg)
  P_N[i] = Verd_Pos/(Verd_Pos+Fals_Pos)
  R_N[i] = Verd_Pos/(Verd_Pos+Fals_Neg)

#Obtenemos la curva ROC
plt.plot(cosa1,cosa2,color='red')
plt.plot(TFP_N,TVP_N,color='blue')
plt.xlabel('Tasa falsos positivos')
plt.ylabel('Tasa verdaderos positivos')
plt.title('Curva ROC al usar el modelo gaussiano')
plt.show()

# %%
# ACTIVIDAD 19


#Generamos la curva precission-recall
plt.plot(algo1,cosa2,color='red')
plt.plot(R_N,P_N,color='blue')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Curva Precision-Recall al usar el modelo gaussiano')
plt.show()

# %%
#PARTE 4

# ACTIVIDAD 20


#Graficamos ambas curvas ROC en un mismo grafico
plt.plot(TFP,TVP,label='Al usar histogramas',color='blue')
plt.plot(TFP_N,TVP_N,label='Al usar gaussiana',color='orange')
plt.plot(cosa1,cosa2,color='red')
plt.xlabel('Tasa falsos positivos')
plt.ylabel('Tasa verdaderos positivos')
plt.legend()
plt.title('Curva ROC')
plt.show()

# %%
# ACTIVIDAD 21


#Graficamos las curvas de precision-recall en un unico grafico
plt.plot(algo1,cosa2,color='red')
plt.plot(R,P,label='Al usar histogramas',color='blue')
plt.plot(R_N,P_N,label='Al usar gaussiana',color='orange')
plt.xlabel('Recall')
plt.ylabel('Precission')
plt.legend()
plt.title('Curva precision-recall')
plt.show()

# %%
# ACTIVIDAD 22


print('Al usar histogramas el programa tarda',tiempo_hist)
print('y')
print('Al usar el modelo gaussiano el programa tarda',tiempo_gauss)
# Out:
# Al usar histogramas el programa tarda 1617827162.8089943
# y
# Al usar el modelo gaussiano el programa tarda 1617827230.4603605
